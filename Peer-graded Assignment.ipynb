# %% [markdown]
# # My Jupiter Notebook on  IBM Watson Studio

# %% [markdown]
# **Diego Javier Morales Camacho** <br>
# Data processor Level 2, I would like to be a Data Scientist

# %% [markdown]
# *I am interested in data science because i want to start developing new features to the company i work for and some day <br>
# I would like to be independant and have my own data science projects*

# %% [markdown]
# ### At the following Cell my code will sum 5+6

# %%
5+6
# Out:
# 11

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <b>Hello:</b><br>
#         1. Esto es una lista<br>
#         2. La lista continúa
# </div>
#
# ***
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/1200px-Jupyter_logo.svg.png" alt="Jupyther Logo" title="My first image" />
